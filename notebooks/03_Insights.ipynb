# %% [markdown]
# # Insights
# Summarize the most popular courses, learner segments, and enrollment trends.

# %%
import pandas as pd
from src.analysis import *
data = pd.read_csv('../data/processed/merged_data.csv', parse_dates=['EnrollmentDate'])
print(kpis(data))
print(course_popularity(data).head())
